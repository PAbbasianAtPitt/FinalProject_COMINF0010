# %% [markdown]
# Public Art in the Neighborhoods of Pittsburgh
# Diana Randall
# I chose public art because I think it is important for art to be accessible in a neighborhood and it brings more attention to the area

# %%
#Import pandas 
import pandas as pd;
import numpy as np;
#read in dataset
data = pd.read_csv("publicArt.csv")
#make variable for neighborhoods specifically
neighborhood = data.neighborhood
neighborhood.value_counts()

# %%
from matplotlib import pyplot as plt
neighborhood.value_counts().head(20).plot(kind='bar')
plt.title("Amount of Public Art in Pittsburgh Neighborhoods")
plt.xlabel("Neighborhood")
plt.ylabel("Number of Works")
#Create graph
# Out:
# Text(0, 0.5, 'Number of Works')

# %%
#Central Business District has the most art then Squirrel Hill and Allegheny Center
popData = pd.read_csv("population.csv")

# %%
popData1 = popData[["Neighborhood","Estimate; Total"]]
popData1.head(20)
#Get top 20 neighborhoods for population
# Out:
#                  Neighborhood  Estimate; Total
# 0            Allegheny Center             1411
# 1              Allegheny West              343
# 2                   Allentown             2558
# 3                   Arlington             1852
# 4           Arlington Heights              272
# 5                  Banksville             3858
# 6           Bedford Dwellings             1349
# 7                   Beechview             8078
# 8                 Beltzhoover             1702
# 9                  Bloomfield             8669
# 10                      Bluff             6294
# 11                    Bon Air              920
# 12           Brighton Heights             7421
# 13                  Brookline            13160
# 14       California-Kirkbride              803
# 15                    Carrick            10122
# 16  Central Business District             4060
# 17      Central Lawrenceville             4775
# 18          Central Northside             2892
# ...

# %%
central = 27/4060
squirrelSouth = 22/16042
allegheny = 18/1411
southFlat = 10/6292
highland = 10/6810
print(central," ",squirrelSouth," ",allegheny," ",southFlat," ",highland)
#Finds art per capita for top five neighborhoods
# Out:
# 0.006650246305418719   0.0013714000748036405   0.012756909992912827   0.001589319771137953   0.0014684287812041115

# %% [markdown]
# While in the beginning it may have seemed as if the Central Business District was the best neighborhood based on how many public art pieces were in the neighborhood, after factoring in the differing population sizes for the top five neighborhoods originally found; the best neighborhood was found to be Allegheny Center. The neighborhood with the most art per capita is Allegheny Center! Because of this I think Allegheny Center is the best neighborhood in Pittsburgh. I think factoring in the population is important because I feel that it is more important to have a higher density of art rather than a higher amount.

# %% [markdown]
# ![image.png](attachment:688d6c70-38f6-4bac-b5ad-4a8c59bfc3e5.png)

# %% [markdown]
# My personal favorite from this area is from a series Sidney Waugh did. This piece is called The Heavens
